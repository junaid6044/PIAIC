# %% [markdown]
# # **Description of the dataset**
#
# The describe function in pandas is a convenient method that provides summary statistics of a DataFrame or Series. It
# computes various descriptive statistics, such as count, mean, standard deviation, minimum, quartiles, and maximum, for
# the numerical columns in the DataFrame.
#
# Here is a breakdown of the statistics provided by the **.describe()** function:
#
# 1. **Count**: The number of non-null values in each column.
# 2. **Mean:** The average value of each column.
# 3. **Standard Deviation (std):** The measure of the amount of variation or dispersion in each column.
# 4. **Minimum (min):** The smallest value in each column.
# 5. **25th Percentile (25%):** Also known as the first quartile (Q1), this represents the value below which 25% of the data
# falls.
# 6. **50th Percentile (50%):** Also known as the median, this represents the value below which 50% of the data falls.
# 7. **75th Percentile (75%):** Also known as the third quartile (Q3), this represents the value below which 75% of the data
# falls.
# 8. **Maximum (max):** The largest value in each column.

# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (2.1.4)
# Requirement already satisfied: numpy<2,>=1.22.4 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %%
import pandas as pd
df = pd.read_csv("sample_data/california_housing_test.csv")

# %%
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.05     37.37                27.0       3885.0           661.0
# 1    -118.30     34.26                43.0       1510.0           310.0
# 2    -117.81     33.78                27.0       3589.0           507.0
# 3    -118.36     33.82                28.0         67.0            15.0
# 4    -119.67     36.33                19.0       1241.0           244.0
#
#    population  households  median_income  median_house_value
# 0      1537.0       606.0         6.6085            344700.0
# 1       809.0       277.0         3.5990            176500.0
# 2      1484.0       495.0         5.7934            270500.0
# 3        49.0        11.0         6.1359            330000.0
# 4       850.0       237.0         2.9375             81700.0

# %%
df.describe()
# Out:
#          longitude    latitude  housing_median_age   total_rooms  \
# count  3000.000000  3000.00000         3000.000000   3000.000000
# mean   -119.589200    35.63539           28.845333   2599.578667
# std       1.994936     2.12967           12.555396   2155.593332
# min    -124.180000    32.56000            1.000000      6.000000
# 25%    -121.810000    33.93000           18.000000   1401.000000
# 50%    -118.485000    34.27000           29.000000   2106.000000
# 75%    -118.020000    37.69000           37.000000   3129.000000
# max    -114.490000    41.92000           52.000000  30450.000000
#
#        total_bedrooms    population  households  median_income  \
# count     3000.000000   3000.000000  3000.00000    3000.000000
# mean       529.950667   1402.798667   489.91200       3.807272
# std        415.654368   1030.543012   365.42271       1.854512
# min          2.000000      5.000000     2.00000       0.499900
# 25%        291.000000    780.000000   273.00000       2.544000
# 50%        437.000000   1155.000000   409.50000       3.487150
# 75%        636.000000   1742.750000   597.25000       4.656475
# max       5419.000000  11935.000000  4930.00000      15.000100
#
#        median_house_value
# count          3000.00000
# mean         205846.27500
# std          113119.68747
# min           22500.00000
# 25%          121200.00000
# 50%          177650.00000
# 75%          263975.00000
# max          500001.00000

# %%
df['total_rooms'].describe()
# Out:
# count     3000.000000
# mean      2599.578667
# std       2155.593332
# min          6.000000
# 25%       1401.000000
# 50%       2106.000000
# 75%       3129.000000
# max      30450.000000
# Name: total_rooms, dtype: float64

# %%
df.iloc[299]
# Out:
# longitude               -122.3000
# latitude                  37.9700
# housing_median_age        34.0000
# total_rooms             2854.0000
# total_bedrooms           528.0000
# population              1211.0000
# households               452.0000
# median_income              3.5353
# median_house_value    164700.0000
# Name: 299, dtype: float64

# %%
df.sort_values(by = "total_bedrooms").head()
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 1115    -116.95     33.86                 1.0          6.0             2.0
# 2640    -114.62     33.62                26.0         18.0             3.0
# 740     -117.12     32.66                52.0         16.0             4.0
# 1355    -117.11     32.66                52.0         25.0             5.0
# 2690    -118.06     34.03                36.0         21.0             7.0
#
#       population  households  median_income  median_house_value
# 1115         8.0         2.0          1.625             55000.0
# 2640         5.0         3.0          0.536            275000.0
# 740          8.0         3.0          1.125             60000.0
# 1355        14.0         9.0          1.625            118800.0
# 2690        21.0         9.0          2.375            175000.0

# %%
df.sort_values (by = "total_bedrooms", ascending=False).head()
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 1563    -118.44     33.98                21.0      18132.0          5419.0
# 2429    -117.20     33.58                 2.0      30450.0          5033.0
# 978     -121.53     38.48                 5.0      27870.0          5027.0
# 2014    -117.22     32.86                 4.0      16289.0          4585.0
# 292     -116.36     33.78                 6.0      24121.0          4522.0
#
#       population  households  median_income  median_house_value
# 1563      7431.0      4930.0         5.3359            500001.0
# 2429      9419.0      3197.0         4.5936            174300.0
# 978      11935.0      4855.0         4.8811            212200.0
# 2014      7604.0      4176.0         3.6287            280800.0
# 292       4176.0      2221.0         3.3799            239300.0

# %%
df ["population" ].head(10)
# Out:
# 0    1537.0
# 1     809.0
# 2    1484.0
# 3      49.0
# 4     850.0
# 5     663.0
# 6     604.0
# 7    1341.0
# 8    1446.0
# 9    2830.0
# Name: population, dtype: float64

# %%
df[df["population"] ==7431.0]
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 1563    -118.44     33.98                21.0      18132.0          5419.0
#
#       population  households  median_income  median_house_value
# 1563      7431.0      4930.0         5.3359            500001.0

# %%
after_7431 = df[ "population"] > 7431
print(after_7431)
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2995    False
# 2996    False
# 2997    False
# 2998    False
# 2999    False
# Name: population, Length: 3000, dtype: bool

# %%
after_7431 = df[ "population"] > 7431
df [after_7431]
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 33      -118.08     34.55                 5.0      16181.0          2971.0
# 321     -121.73     37.68                17.0      20354.0          3493.0
# 947     -117.23     33.91                 9.0      11654.0          2100.0
# 978     -121.53     38.48                 5.0      27870.0          5027.0
# 1146    -117.27     33.15                 4.0      23915.0          4135.0
# 1283    -117.18     32.92                 4.0      15025.0          2616.0
# 1597    -117.12     33.49                 4.0      21988.0          4055.0
# 2014    -117.22     32.86                 4.0      16289.0          4585.0
# 2186    -116.14     34.45                12.0       8796.0          1721.0
# 2429    -117.20     33.58                 2.0      30450.0          5033.0
#
#       population  households  median_income  median_house_value
# 33        8152.0      2651.0         4.5237            141800.0
# 321       8768.0      3293.0         5.4496            238900.0
# 947       7596.0      2127.0         4.0473            127200.0
# 978      11935.0      4855.0         4.8811            212200.0
# 1146     10877.0      3958.0         4.6357            244900.0
# 1283      7560.0      2392.0         5.1960            210700.0
# 1597      8824.0      3252.0         3.9963            191100.0
# 2014      7604.0      4176.0         3.6287            280800.0
# 2186     11139.0      1680.0         2.2612            137500.0
# 2429      9419.0      3197.0         4.5936            174300.0

# %%
mid_2000 = df[ "population"].between(2000, 2010)
df[mid_2000]
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 384     -122.42     37.76                52.0       2038.0           629.0
# 421     -118.21     33.90                35.0       2420.0           579.0
# 503     -119.80     36.82                24.0       5377.0          1005.0
# 1268    -117.94     34.06                32.0       3418.0           662.0
# 1428    -117.04     32.62                26.0       3620.0           607.0
# 1669    -117.09     32.75                19.0       2739.0           707.0
# 1828    -117.56     34.42                 6.0       4264.0           749.0
# 2244    -120.52     35.24                 5.0       4413.0           804.0
# 2256    -118.60     34.21                19.0       2581.0           857.0
# 2297    -118.10     33.97                35.0       2426.0           529.0
# 2339    -117.88     34.11                30.0       3082.0           602.0
# 2370    -122.05     37.31                25.0       4601.0           696.0
# 2585    -120.78     38.74                28.0       4236.0           877.0
#
#       population  households  median_income  median_house_value
# 384       2007.0       596.0         2.5701            266700.0
# 421       2010.0       540.0         2.0817            104600.0
# 503       2010.0       982.0         3.4542            121200.0
# 1268      2003.0       622.0         4.0333            210200.0
# 1428      2000.0       593.0         4.9962            156000.0
# 1669      2004.0       622.0         1.6318            117700.0
# 1828      2005.0       666.0         3.4695            138800.0
# 2244      2003.0       725.0         5.0267            253300.0
# 2256      2004.0       784.0         2.6159            182300.0
# 2297      2010.0       514.0         2.9922            163500.0
# 2339      2008.0       619.0         4.1411            182700.0
# 2370      2003.0       666.0         8.0727            455500.0
# 2585      2008.0       881.0         2.1603            111300.0
